# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %%
face = sp.misc.face()
ascent = sp.misc.ascent()

# %%
plt.imshow(face)

# %%
plt.imshow(ascent)
